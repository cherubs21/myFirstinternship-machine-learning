# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Loan_Train.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
vals_to_replace = {'Male':'1', 'Female':'2'}
df['Gender'] = df['Gender'].map(vals_to_replace)
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002      1      No          0      Graduate            No
# 1    LP001003      1     Yes          1      Graduate            No
# 2    LP001005      1     Yes          0      Graduate           Yes
# 3    LP001006      1     Yes          0  Not Graduate            No
# 4    LP001008      1      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 609  LP002978      2      No          0      Graduate            No
# 610  LP002979      1     Yes         3+      Graduate            No
# 611  LP002983      1     Yes          1      Graduate            No
# 612  LP002984      1     Yes          2      Graduate            No
# 613  LP002990      2      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
vals_to_replace1 = {'Graduate':'1', 'Not Graduate':'2'}
df['Education'] = df['Education'].map(vals_to_replace1)
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002      1      No          0         1            No
# 1    LP001003      1     Yes          1         1            No
# 2    LP001005      1     Yes          0         1           Yes
# 3    LP001006      1     Yes          0         2            No
# 4    LP001008      1      No          0         1            No
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      2      No          0         1            No
# 610  LP002979      1     Yes         3+         1            No
# 611  LP002983      1     Yes          1         1            No
# 612  LP002984      1     Yes          2         1            No
# 613  LP002990      2      No          0         1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
vals_to_replace2 = {'No':'0', 'Yes':'1'}
df['Married'] = df['Married'].map(vals_to_replace2)
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002      1       0          0         1            No
# 1    LP001003      1       1          1         1            No
# 2    LP001005      1       1          0         1           Yes
# 3    LP001006      1       1          0         2            No
# 4    LP001008      1       0          0         1            No
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      2       0          0         1            No
# 610  LP002979      1       1         3+         1            No
# 611  LP002983      1       1          1         1            No
# 612  LP002984      1       1          2         1            No
# 613  LP002990      2       0          0         1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
vals_to_replace3 = {'No':'0', 'Yes':'1'}
df['Self_Employed'] = df['Self_Employed'].map(vals_to_replace3)
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002      1       0          0         1             0
# 1    LP001003      1       1          1         1             0
# 2    LP001005      1       1          0         1             1
# 3    LP001006      1       1          0         2             0
# 4    LP001008      1       0          0         1             0
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      2       0          0         1             0
# 610  LP002979      1       1         3+         1             0
# 611  LP002983      1       1          1         1             0
# 612  LP002984      1       1          2         1             0
# 613  LP002990      2       0          0         1             1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df['Dependents'] = df['Dependents'].replace('3+','3')

# %%
vals_to_replace4 = {'Urban':'0', 'Rural':'1','Semiurban':'2'}
df['Property_Area'] = df['Property_Area'].map(vals_to_replace4)
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002      1       0          0         1             0
# 1    LP001003      1       1          1         1             0
# 2    LP001005      1       1          0         1             1
# 3    LP001006      1       1          0         2             0
# 4    LP001008      1       0          0         1             0
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      2       0          0         1             0
# 610  LP002979      1       1          3         1             0
# 611  LP002983      1       1          1         1             0
# 612  LP002984      1       1          2         1             0
# 613  LP002990      2       0          0         1             1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
vals_to_replace5 = {'N':'0', 'Y':'1'}
df['Loan_Status'] = df['Loan_Status'].map(vals_to_replace5)
df
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002      1       0          0         1             0
# 1    LP001003      1       1          1         1             0
# 2    LP001005      1       1          0         1             1
# 3    LP001006      1       1          0         2             0
# 4    LP001008      1       0          0         1             0
# ..        ...    ...     ...        ...       ...           ...
# 609  LP002978      2       0          0         1             0
# 610  LP002979      1       1          3         1             0
# 611  LP002983      1       1          1         1             0
# 612  LP002984      1       1          2         1             0
# 613  LP002990      2       0          0         1             1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df=df.drop(["Loan_ID"], axis=1)
df
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# 610      1       1          3         1             0             4106
# 611      1       1          1         1             0             8072
# 612      1       1          2         1             0             7583
# 613      2       0          0         1             1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
mean_value=df['LoanAmount'].mean()
mean_value
# Out:
# 146.41216216216216

# %%
df['LoanAmount'].fillna(value=mean_value, inplace=True)
df
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# 610      1       1          3         1             0             4106
# 611      1       1          1         1             0             8072
# 612      1       1          2         1             0             7583
# 613      2       0          0         1             1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
mean_value=df['Credit_History'].mean()
mean_value
# Out:
# 0.8421985815602837

# %%
df['Credit_History'].fillna(value=mean_value, inplace=True)
df
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# 610      1       1          3         1             0             4106
# 611      1       1          1         1             0             8072
# 612      1       1          2         1             0             7583
# 613      2       0          0         1             1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# 610      1       1          3         1             0             4106
# 611      1       1          1         1             0             8072
# 612      1       1          2         1             0             7583
# 613      2       0          0         1             1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df=df.dropna(subset=['Gender','Married'])
df
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# 610      1       1          3         1             0             4106
# 611      1       1          1         1             0             8072
# 612      1       1          2         1             0             7583
# 613      2       0          0         1             1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
mean_value=df['Loan_Amount_Term'].mean()
mean_value
# Out:
# 341.9178082191781

# %%
df['Loan_Amount_Term'].fillna(value=mean_value, inplace=True)
df
# Out:
# C:\Users\jinoh\AppData\Local\Temp\ipykernel_26008\2160401849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Loan_Amount_Term'].fillna(value=mean_value, inplace=True)
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# ...

# %%
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents           12
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
median_value=df['Dependents'].median()
median_value
# Out:
# 0.0

# %%
df['Dependents'].fillna(value=mean_value, inplace=True)
df
# Out:
# C:\Users\jinoh\AppData\Local\Temp\ipykernel_26008\1746680543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dependents'].fillna(value=mean_value, inplace=True)
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# ...

# %%
median_value=df['Self_Employed'].median()
median_value
# Out:
# 0.0

# %%
df['Self_Employed'].fillna(value=mean_value, inplace=True)
df
# Out:
# C:\Users\jinoh\AppData\Local\Temp\ipykernel_26008\1321177260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Self_Employed'].fillna(value=mean_value, inplace=True)
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0        1       0          0         1             0             5849
# 1        1       1          1         1             0             4583
# 2        1       1          0         1             1             3000
# 3        1       1          0         2             0             2583
# 4        1       0          0         1             0             6000
# ..     ...     ...        ...       ...           ...              ...
# 609      2       0          0         1             0             2900
# ...

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
X=df[['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area']]
y=df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
X_train
# Out:
#     Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 360      2       0          1         1             0             4723
# 299      1       1          1         1             0             2014
# 158      1       0          0         1    341.917808             2980
# 409      1       1          3         1             0            81000
# 319      1       1          1         1             1            10000
# ..     ...     ...        ...       ...           ...              ...
# 492      1       0          0         2             0             3691
# 430      2       0          1         1             1             8624
# 121      2       0          0         1             0             4166
# 262      2       0          1         1             0             3481
# 255      2       0          3         1             0             3083
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X_train, y_train)

# %%
clf = DecisionTreeClassifier(max_depth=None, min_samples_split=2,
...     random_state=0)
scores = cross_val_score(clf, X, y, cv=2)
scores.mean()
# Out:
# 0.7073578595317725

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.5333333333333333

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.7666666666666667
# C:\Users\jinoh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
